# %% [markdown]
# <a href="https://colab.research.google.com/github/jesus-2025/MY_PROJECT-/blob/main/second(2)_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Step 2: Define the correct file path in Google Drive
file_path = '/content/drive/My Drive/original dataset.xlsx'

# %%
# Step 3: Read the Excel file using pandas
import pandas as pd
file_path = '/content/drive/My Drive/original dataset.xlsx'
df = pd.read_excel(file_path)

# Display the first few rows
df.head()
# Out:
#    Number      Sleep   Appetite   Interest   Fatigue Worthlessness  \
# 0       1  Very High  Very High  Very High      High      Moderate
# 1       2   Very Low  Very High  Very High  Moderate      Moderate
# 2       3       High        Low        Low  Moderate          High
# 3       4   Very Low  Very High  Very High  Moderate      Very Low
# 4       5        Low        Low   Moderate      High      Very Low
#
#   Concentration  Agitation Suicidal Ideation Sleep Disturbance Aggression  \
# 0     Very High       High         Very High          Moderate       High
# 1           Low   Moderate               Low               Low       High
# 2      Moderate  Very High          Moderate         Very High   Very Low
# 3          High   Very Low               Low              High       High
# 4     Very High  Very High               Low              High        Low
#
#   Panic Attacks Hopelessness Restlessness Low Energy Depression State
# 0          High     Very Low     Very Low   Moderate             Mild
# 1     Very High         High    Very High       High         Moderate
# 2     Very High    Very High    Very High       High         Moderate
# 3           Low     Moderate         High        Low         Moderate
# 4     Very High          Low          Low        Low           Severe

# %% [markdown]
# PREPROCESSED DATA 1

# %%
import pandas as pd

# Load your dataset
df = pd.read_excel('/content/drive/My Drive/original dataset.xlsx')

# Mapping for all attributes (except 'Depression State')
level_mapping = {
    'Very Low': 1,
    'Low': 2,
    'Moderate': 3,
    'High': 4,
    'Very High': 5
}

# Mapping for Depression State
depression_mapping = {
    'None': 0,
    'Mild': 1,
    'Moderate': 2,
    'Severe': 3
}

# Columns to apply level mapping (exclude Number and Depression State)
columns_to_map = [col for col in df.columns if col not in ['Number', 'Depression State']]

# Apply mapping to symptom columns
df[columns_to_map] = df[columns_to_map].applymap(lambda x: level_mapping.get(x, x))

# Apply mapping to Depression State separately
df['Depression State'] = df['Depression State'].map(depression_mapping)

# Save the updated dataset
df.to_excel('/content/drive/My Drive/final_converted_dataset.xlsx', index=False)

print("✅ Dataset successfully converted and saved to Google Drive.")
# Out:
# <ipython-input-6-8439a999034e>:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[columns_to_map] = df[columns_to_map].applymap(lambda x: level_mapping.get(x, x))
# ✅ Dataset successfully converted and saved to Google Drive.

# %% [markdown]
# FEATURE EXTRACTION

# %%
import pandas as pd
import numpy as np

# Load the existing preprocessed dataset
df = pd.read_excel('/content/drive/My Drive/final_converted_dataset.xlsx')

# Number of rows in the dataset
num_rows = df.shape[0]

# Add synthetic "Age" feature (random between 18 and 60)
df['Age'] = np.random.randint(18, 61, size=num_rows)

# Add synthetic "Gender" feature (random choice)
df['Gender'] = np.random.choice(['Male', 'Female', 'Other'], size=num_rows)

# Add synthetic "Past_Mental_Health_History" feature
df['Past_Mental_Health_History'] = np.random.choice(['Yes', 'No'], size=num_rows, p=[0.3, 0.7])  # 30% Yes, 70% No

# Add synthetic "Social_Support_Level" feature (1 to 5 scale)
df['Social_Support_Level'] = np.random.randint(1, 6, size=num_rows)

# Save the updated dataset
df.to_excel('/content/drive/My Drive/enhanced_dataset.xlsx', index=False)

print("✅ New features added and dataset saved as 'enhanced_dataset.xlsx'")
# Out:
# ✅ New features added and dataset saved as 'enhanced_dataset.xlsx'

# %% [markdown]
# INCRESING THE ENTRY

# %%
# !pip install sdv
# Out:
# Collecting sdv
#   Downloading sdv-1.20.0-py3-none-any.whl.metadata (14 kB)
# Collecting boto3<2.0.0,>=1.28 (from sdv)
#   Downloading boto3-1.38.3-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore<2.0.0,>=1.31 (from sdv)
#   Downloading botocore-1.38.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.0.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.2.2)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.67.1)
# Collecting copulas>=0.12.1 (from sdv)
#   Downloading copulas-0.12.2-py3-none-any.whl.metadata (9.4 kB)
# Collecting ctgan>=0.11.0 (from sdv)
#   Downloading ctgan-0.11.0-py3-none-any.whl.metadata (10 kB)
# Collecting deepecho>=0.7.0 (from sdv)
#   Downloading deepecho-0.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting rdt>=1.16.0 (from sdv)
#   Downloading rdt-1.16.0-py3-none-any.whl.metadata (10 kB)
# Collecting sdmetrics>=0.20.1 (from sdv)
#   Downloading sdmetrics-0.20.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.3.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (6.0.2)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.13.0,>=0.12.0 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading s3transfer-0.12.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.3.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (1.14.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ctgan>=0.11.0->sdv) (2.6.0+cu124)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.16.0->sdv) (1.6.1)
# Collecting Faker>=17 (from rdt>=1.16.0->sdv)
#   Downloading faker-37.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.16.0->sdv) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.16.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv) (3.0.2)
# Downloading sdv-1.20.0-py3-none-any.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.9/157.9 kB 3.9 MB/s eta 0:00:00
# Downloading boto3-1.38.3-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 9.7 MB/s eta 0:00:00
# Downloading botocore-1.38.3-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 74.7 MB/s eta 0:00:00
# Downloading copulas-0.12.2-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.6 MB/s eta 0:00:00
# Downloading ctgan-0.11.0-py3-none-any.whl (24 kB)
# Downloading deepecho-0.7.0-py3-none-any.whl (27 kB)
# Downloading rdt-1.16.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 kB 4.7 MB/s eta 0:00:00
# Downloading sdmetrics-0.20.1-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 12.8 MB/s eta 0:00:00
# Downloading faker-37.1.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 52.7 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.12.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 6.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 51.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 56.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jmespath, Faker, nvidia-cusparse-cu12, nvidia-cudnn-cu12, botocore, s3transfer, rdt, nvidia-cusolver-cu12, copulas, sdmetrics, boto3, deepecho, ctgan, sdv
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed Faker-37.1.0 boto3-1.38.3 botocore-1.38.3 copulas-0.12.2 ctgan-0.11.0 deepecho-0.7.0 jmespath-1.0.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 rdt-1.16.0 s3transfer-0.12.0 sdmetrics-0.20.1 sdv-1.20.0

# %%
from sdv.single_table import CTGANSynthesizer

# %%
# Step 1: Install the latest SDV version
# !pip install sdv --upgrade

# Step 2: Import required libraries
import pandas as pd
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata
from sklearn.preprocessing import LabelEncoder

# Step 3: Load your dataset
file_path = "/content/drive/My Drive/enhanced_dataset.xlsx"  # Update path if needed
df = pd.read_excel(file_path)

# Step 4: Encode categorical columns
label_encoders = {}
for column in df.columns:
    if df[column].dtype == 'object':
        le = LabelEncoder()
        df[column] = le.fit_transform(df[column].astype(str))
        label_encoders[column] = le

# Step 5: Create metadata
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data=df)

# Step 6: Initialize and train CTGAN synthesizer
synthesizer = CTGANSynthesizer(metadata)
synthesizer.fit(df)

# Step 7: Generate 1000 synthetic rows
synthetic_data = synthesizer.sample(1000)

# Step 8: Decode label encoded columns
for column, le in label_encoders.items():
    synthetic_data[column] = le.inverse_transform(
        synthetic_data[column].clip(0, len(le.classes_) - 1).round().astype(int)
    )

# Step 9: Combine original and synthetic data
extended_df = pd.concat([df, synthetic_data], ignore_index=True)

# Step 10: Save the ex

output_path ="/content/drive/My Drive/extended_enhanced_dataset.xlsx"
extended_df.to_excel(output_path, index=False)

print("✅ Extended dataset saved at:", output_path)
# Out:
# Requirement already satisfied: sdv in /usr/local/lib/python3.11/dist-packages (1.20.0)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.3)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.3)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.0.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.2.2)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.67.1)
# Requirement already satisfied: copulas>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.12.2)
# Requirement already satisfied: ctgan>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.11.0)
# Requirement already satisfied: deepecho>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.7.0)
# Requirement already satisfied: rdt>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.16.0)
# Requirement already satisfied: sdmetrics>=0.20.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.1)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.3.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (6.0.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.3.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (1.14.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ctgan>=0.11.0->sdv) (2.6.0+cu124)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.16.0->sdv) (1.6.1)
# Requirement already satisfied: Faker>=17 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.16.0->sdv) (37.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.16.0->sdv) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.16.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv) (3.0.2)
# /usr/local/lib/python3.11/dist-packages/sdv/single_table/base.py:126: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /usr/local/lib/python3.11/dist-packages/sdv/single_table/base.py:105: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# ✅ Extended dataset saved at: /content/drive/My Drive/extended_enhanced_dataset.xlsx

# %% [markdown]
# AFTER EXTENSION PREPROCESSING 2(UPDATION)

# %%
# Step 1: Install the latest SDV version
# !pip install sdv --upgrade

# Step 2: Import required libraries
import pandas as pd
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata
from sklearn.preprocessing import LabelEncoder

# Step 3: Load your dataset
file_path = "/content/drive/My Drive/enhanced_dataset.xlsx"  # Update path if needed
df = pd.read_excel(file_path)

# Step 4: Encode categorical columns in original data (if not already encoded)
label_encoders = {}
for column in df.columns:
    if df[column].dtype == 'object':
        le = LabelEncoder()
        df[column] = le.fit_transform(df[column].astype(str))
        label_encoders[column] = le

# Step 5: Create metadata
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data=df)

# Step 6: Initialize and train CTGAN synthesizer
synthesizer = CTGANSynthesizer(metadata)
synthesizer.fit(df)

# Step 7: Generate 1000 synthetic rows
synthetic_data = synthesizer.sample(1000)

# Step 8: Decode label encoded columns for synthetic data
for column, le in label_encoders.items():
    synthetic_data[column] = le.inverse_transform(
        synthetic_data[column].clip(0, len(le.classes_) - 1).round().astype(int)
    )

# Step 9: Convert the "Depression State", "Gender", and "Past_Mental_Health_History" columns in synthetic data
# Assuming these columns were previously encoded in the range 0-3 for Depression State and 0-2 for Gender
# Map Depression State and Gender back to numerical values (e.g., Mild = 1, Moderate = 2, Severe = 3, None = 0)
depression_mapping = {'None': 0, 'Mild': 1, 'Moderate': 2, 'Severe': 3}
gender_mapping = {'Male': 1, 'Female': 2, 'Other': 3}
past_mental_health_history_mapping = {'Yes': 1, 'No': 0}

# Apply mappings to synthetic data columns (you can adjust mappings if needed)
synthetic_data['Depression State'] = synthetic_data['Depression State'].map(depression_mapping)
synthetic_data['Gender'] = synthetic_data['Gender'].map(gender_mapping)
synthetic_data['Past_Mental_Health_History'] = synthetic_data['Past_Mental_Health_History'].map(past_mental_health_history_mapping)

# Step 10: Combine original and synthetic data
extended_df = pd.concat([df, synthetic_data], ignore_index=True)

# Step 11: Save the extended dataset
output_path = "/content/drive/My Drive/extended_enhanced_dataset.xlsx"
extended_df.to_excel(output_path, index=False)

print("✅ Extended dataset saved at:", output_path)
# Out:
# Requirement already satisfied: sdv in /usr/local/lib/python3.11/dist-packages (1.20.0)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.3)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.3)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.0.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.2.2)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.67.1)
# Requirement already satisfied: copulas>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.12.2)
# Requirement already satisfied: ctgan>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.11.0)
# Requirement already satisfied: deepecho>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.7.0)
# Requirement already satisfied: rdt>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.16.0)
# Requirement already satisfied: sdmetrics>=0.20.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.1)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.3.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (6.0.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.3.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (1.14.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ctgan>=0.11.0->sdv) (2.6.0+cu124)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.16.0->sdv) (1.6.1)
# Requirement already satisfied: Faker>=17 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.16.0->sdv) (37.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.16.0->sdv) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.16.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv) (3.0.2)
# /usr/local/lib/python3.11/dist-packages/sdv/single_table/base.py:126: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /usr/local/lib/python3.11/dist-packages/sdv/single_table/base.py:105: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# ✅ Extended dataset saved at: /content/drive/My Drive/extended_enhanced_dataset.xlsx

# %%
CHANGING ONLY THE TWO COLUMNS UPDATING THE ABOVE CODE

# %%
import pandas as pd

# Load your dataset
file_path = "/content/drive/My Drive/extended_enhanced_dataset.xlsx"  # Update your dataset path
df = pd.read_excel(file_path)

# Step 1: Change 'Number' column to be continuous from 1 to 1000
df['Number'] = range(1, len(df) + 1)

# Step 2: Predict Depression State after 540 rows (assuming we already have Depression State for the first 540)
# You can use an if-else block or some heuristic model based on existing features to predict.
# Here, we will use a simple rule-based approach (you can modify it later as needed):
def predict_depression_state(row):
    if row['Sleep'] >= 4 and row['Fatigue'] >= 4:
        return 3  # Severe
    elif row['Interest'] <= 2 and row['Worthlessness'] >= 3:
        return 2  # Moderate
    elif row['Appetite'] >= 4 and row['Concentration'] >= 4:
        return 1  # Mild
    else:
        return 0  # None

# Apply the depression prediction for rows after 540
df.loc[540:, 'Depression State'] = df.loc[540:].apply(predict_depression_state, axis=1)

# Step 3: Convert `Depression State` to numerical format (already done above)
# 1 = Mild, 2 = Moderate, 3 = Severe, 0 = None

# Step 4: Convert Gender to numerical format (Male = 1, Female = 2, Other = 3)
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 2, 'Other': 3})

# Step 5: Convert Past Mental Health History to numerical format (Yes = 1, No = 0)
df['Past_Mental_Health_History'] = df['Past_Mental_Health_History'].map({'Yes': 1, 'No': 0})

# Save the updated dataset to a new Excel file
output_path = "/content/drive/My Drive/updated_extended_enhanced_dataset.xlsx"
df.to_excel(output_path, index=False)

print("✅ Dataset updated and saved successfully!")
# Out:
# ✅ Dataset updated and saved successfully!

# %% [markdown]
# GENDER AND PAST MENTAL HEALTH UPDATION

# %%
import pandas as pd

# Step 1: Load the dataset
file_path = "/content/drive/My Drive/extended_enhanced_dataset.xlsx"  # Update the path if needed
df = pd.read_excel(file_path)

# Step 2: Change 'Number' column to be continuous from 1 to 1000
df['Number'] = range(1, len(df) + 1)

# Step 3: Predict Depression State after 540 rows (assuming we already have Depression State for the first 540)
# You can use an if-else block or some heuristic model based on existing features to predict.
# Here, we will use a simple rule-based approach (you can modify it later as needed):
def predict_depression_state(row):
    if row['Sleep'] >= 4 and row['Fatigue'] >= 4:
        return 3  # Severe
    elif row['Interest'] <= 2 and row['Worthlessness'] >= 3:
        return 2  # Moderate
    elif row['Appetite'] >= 4 and row['Concentration'] >= 4:
        return 1  # Mild
    else:
        return 0  # None

# Apply the depression prediction for rows after 540
df.loc[540:, 'Depression State'] = df.loc[540:].apply(predict_depression_state, axis=1)

# Step 4: Convert `Depression State` to numerical format (already done above)
# 1 = Mild, 2 = Moderate, 3 = Severe, 0 = None

# Step 5: Convert Gender to numerical format (Male = 1, Female = 2, Other = 3)
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 2, 'Other': 3})
df['Gender'].fillna(0, inplace=True)  # For rows where gender is missing, assign 'Other' (value = 0)

# Step 6: Convert Past Mental Health History to numerical format (Yes = 1, No = 0)
df['Past_Mental_Health_History'] = df['Past_Mental_Health_History'].map({'Yes': 1, 'No': 0})
df['Past_Mental_Health_History'].fillna(0, inplace=True)  # For rows where history is missing, assign 'No' (value = 0)

# Step 7: Save the updated dataset to a new Excel file
output_path = "/content/drive/My Drive/updated_extended_enhanced_dataset.xlsx"  # Change this path if needed
df.to_excel(output_path, index=False)

print("✅ Dataset updated and saved successfully!")
# Out:
# <ipython-input-14-0826fdbabae2>:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(0, inplace=True)  # For rows where gender is missing, assign 'Other' (value = 0)
# <ipython-input-14-0826fdbabae2>:35: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Past_Mental_Health_History'].fillna(0, inplace=True)  # For rows where history is missing, assign 'No' (value = 0)
# ✅ Dataset updated and saved successfully!

# %% [markdown]
# zeros change dto ionly female and no

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel('/content/drive/My Drive/updated_extended_enhanced_dataset.xlsx')

# Replace values in 'Gender' column
gender_mapping = {0: 'Female', 1: 'Male', 2: 'Others'}
df['Gender'] = df['Gender'].replace(gender_mapping)

# Replace values in 'Past_Mental_Health_History' column
mental_health_mapping = {0: 'No', 1: 'Yes'}
df['Past_Mental_Health_History'] = df['Past_Mental_Health_History'].replace(mental_health_mapping)

# Save the updated DataFrame to a new Excel file
df.to_excel('/content/drive/My Drive/final_updated_dataset.xlsx', index=False)

print("✅ File saved successfully as 'final_updated_dataset.xlsx'")
# Out:
# ✅ File saved successfully as 'final_updated_dataset.xlsx'

# %%
both  col have been changed

# %%
import pandas as pd
import random

# Load the dataset
df = pd.read_excel('/content/drive/My Drive/final_updated_dataset.xlsx')

# Randomly assign Gender values
df['Gender'] = [random.choice(['Male', 'Female', 'Others']) for _ in range(len(df))]

# Randomly assign Past Mental Health History values
df['Past_Mental_Health_History'] = [random.choice(['Yes', 'No']) for _ in range(len(df))]

# Show value counts to verify changes
print(df['Gender'].value_counts())
print(df['Past_Mental_Health_History'].value_counts())

# Optional: Save the updated dataset
df.to_excel('/content/drive/My Drive/filled_gender_mental_health_dataset.xlsx', index=False)
# Out:
# Gender
# Male      520
# Female    512
# Others    508
# Name: count, dtype: int64
# Past_Mental_Health_History
# Yes    774
# No     766
# Name: count, dtype: int64

# %%
final number format dataset

# %%
import pandas as pd

# Load the dataset
df = pd.read_excel('/content/drive/My Drive/filled_gender_mental_health_dataset.xlsx')

# Convert Gender to numeric
gender_mapping = {'Male': 1, 'Female': 2, 'Others': 0}
df['Gender'] = df['Gender'].map(gender_mapping)

# Convert Past_Mental_Health_History to numeric
mental_health_mapping = {'No': 0, 'Yes': 1}
df['Past_Mental_Health_History'] = df['Past_Mental_Health_History'].map(mental_health_mapping)

# Show unique values to verify
print(df['Gender'].unique())
print(df['Past_Mental_Health_History'].unique())

# Save the updated dataset
df.to_excel('/content/drive/My Drive/numerical_gender_mental_health_dataset.xlsx', index=False)
# Out:
# [2 1 0]
# [1 0]

# %% [markdown]
# 3 RD MODULE FINAL DEEP LEARNING MODULE

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, TensorDataset
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_excel('/content/drive/My Drive/numerical_gender_mental_health_dataset.xlsx')
# Assuming you want to predict 'Depression State' (adjust if needed)
features = df.drop(['Depression State', 'Number'], axis=1).values # Remove 'Number' column
target = df['Depression State'].values

# Scale features using StandardScaler
scaler = StandardScaler()
features = scaler.fit_transform(features)

# Create TensorDataset
dataset = TensorDataset(torch.tensor(features, dtype=torch.float32),
                        torch.tensor(target, dtype=torch.long))

# Split into train and validation sets
train_dataset, val_dataset = train_test_split(dataset, test_size=0.2, random_state=42)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)


# Define your model
class YourModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(YourModel, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, output_size)  # Output layer with correct number of classes

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Get the input size from your data
input_size = features.shape[1]  # Update if necessary
#output_size = len(df['Depression State'].unique())  # This was already defined before
model = YourModel(input_size, output_size).to(device)  # Pass both input_size and output_size

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)



# Define training and validation functions
def train_epoch(model, data_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0
    correct_preds = 0
    total_preds = 0

    for batch in data_loader:
        inputs, labels = batch
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Convert outputs to class predictions
        _, predicted = torch.max(outputs.data, 1)
        correct_preds += (predicted == labels).sum().item()
        total_preds += labels.size(0)

    avg_loss = running_loss / len(data_loader)
    accuracy = correct_preds / total_preds * 100
    return avg_loss, accuracy

def validate_epoch(model, data_loader, criterion, device):
    model.eval()
    running_loss = 0
    correct_preds = 0
    total_preds = 0

    with torch.no_grad():
        for batch in data_loader:
            inputs, labels = batch
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()

            # Convert outputs to class predictions
            _, predicted = torch.max(outputs.data, 1)
            correct_preds += (predicted == labels).sum().item()
            total_preds += labels.size(0)

    avg_loss = running_loss / len(data_loader)
    accuracy = correct_preds / total_preds * 100
    return avg_loss, accuracy

# Setup for training
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Get the input size from your data
input_size = 18  # Update if necessary
#output_size = len(df['Depression State'].unique())  # This was already defined before
model = YourModel(input_size, output_size).to(device)  # Pass both input_size and output_size


criterion = nn.CrossEntropyLoss()  # Replace with your criterion
optimizer = optim.Adam(model.parameters(), lr=0.001)
best_val_accuracy = 0

# Training loop
epochs = 150
for epoch in range(epochs):
    # Train the model for one epoch
    train_loss, train_accuracy = train_epoch(model, train_loader, criterion, optimizer, device)

    # Validate the model
    val_loss, val_accuracy = validate_epoch(model, val_loader, criterion, device)

    # Save the model if validation accuracy improves
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        torch.save(model.state_dict(), "best_model.pth")
        print(f"✅ Best model saved at epoch {epoch + 1}")

    # Print epoch summary
    print(f"Epoch {epoch + 1}:")
    print(f"  Train Loss = {train_loss:.4f}, Train Accuracy = {train_accuracy:.4f}")
    print(f"  Validation Loss = {val_loss:.4f}, Validation Accuracy = {val_accuracy:.4f}")

# Load the best model after training is complete
model.load_state_dict(torch.load("best_model.pth"))
# Out:
# ✅ Best model saved at epoch 1
# Epoch 1:
#   Train Loss = 1.3659, Train Accuracy = 33.6039
#   Validation Loss = 1.3370, Validation Accuracy = 33.7662
# ✅ Best model saved at epoch 2
# Epoch 2:
#   Train Loss = 1.2930, Train Accuracy = 37.5000
#   Validation Loss = 1.2806, Validation Accuracy = 38.6364
# ✅ Best model saved at epoch 3
# Epoch 3:
#   Train Loss = 1.2229, Train Accuracy = 48.7825
#   Validation Loss = 1.2237, Validation Accuracy = 48.3766
# ✅ Best model saved at epoch 4
# Epoch 4:
#   Train Loss = 1.1661, Train Accuracy = 52.8409
#   Validation Loss = 1.1743, Validation Accuracy = 50.9740
# ✅ Best model saved at epoch 5
# Epoch 5:
#   Train Loss = 1.1147, Train Accuracy = 57.3052
#   Validation Loss = 1.1564, Validation Accuracy = 53.2468
# ✅ Best model saved at epoch 6
# Epoch 6:
#   Train Loss = 1.0778, Train Accuracy = 58.5227
#   Validation Loss = 1.1602, Validation Accuracy = 54.5455
# ✅ Best model saved at epoch 7
# Epoch 7:
#   Train Loss = 1.0461, Train Accuracy = 60.7955
#   Validation Loss = 1.1440, Validation Accuracy = 55.8442
# ✅ Best model saved at epoch 8
# Epoch 8:
#   Train Loss = 1.0297, Train Accuracy = 61.2825
#   Validation Loss = 1.1409, Validation Accuracy = 56.8182
# Epoch 9:
#   Train Loss = 1.0081, Train Accuracy = 63.0682
#   Validation Loss = 1.1460, Validation Accuracy = 56.4935
# ✅ Best model saved at epoch 10
# Epoch 10:
#   Train Loss = 0.9853, Train Accuracy = 64.0422
#   Validation Loss = 1.1426, Validation Accuracy = 57.7922
# Epoch 11:
#   Train Loss = 0.9754, Train Accuracy = 65.1786
#   Validation Loss = 1.1382, Validation Accuracy = 57.1429
# Epoch 12:
#   Train Loss = 0.9571, Train Accuracy = 65.7468
#   Validation Loss = 1.1567, Validation Accuracy = 57.7922
# Epoch 13:
#   Train Loss = 0.9458, Train Accuracy = 65.5032
#   Validation Loss = 1.1421, Validation Accuracy = 57.4675
# Epoch 14:
#   Train Loss = 0.9301, Train Accuracy = 67.1266
#   Validation Loss = 1.1485, Validation Accuracy = 57.1429
# Epoch 15:
#   Train Loss = 0.9183, Train Accuracy = 67.5325
#   Validation Loss = 1.1481, Validation Accuracy = 57.4675
# Epoch 16:
#   Train Loss = 0.9043, Train Accuracy = 67.4513
#   Validation Loss = 1.1411, Validation Accuracy = 57.1429
# Epoch 17:
#   Train Loss = 0.8878, Train Accuracy = 68.3442
#   Validation Loss = 1.1533, Validation Accuracy = 57.4675
# Epoch 18:
#   Train Loss = 0.8770, Train Accuracy = 68.3442
#   Validation Loss = 1.1496, Validation Accuracy = 57.7922
# Epoch 19:
#   Train Loss = 0.8721, Train Accuracy = 68.8312
#   Validation Loss = 1.1567, Validation Accuracy = 57.4675
# Epoch 20:
#   Train Loss = 0.8618, Train Accuracy = 68.1818
#   Validation Loss = 1.1619, Validation Accuracy = 57.1429
# Epoch 21:
#   Train Loss = 0.8481, Train Accuracy = 68.7500
#   Validation Loss = 1.1634, Validation Accuracy = 57.4675
# Epoch 22:
#   Train Loss = 0.8355, Train Accuracy = 69.5617
#   Validation Loss = 1.1623, Validation Accuracy = 56.8182
# Epoch 23:
#   Train Loss = 0.8266, Train Accuracy = 70.7792
#   Validation Loss = 1.1680, Validation Accuracy = 56.4935
# Epoch 24:
#   Train Loss = 0.8129, Train Accuracy = 70.4545
#   Validation Loss = 1.1819, Validation Accuracy = 57.7922
# Epoch 25:
#   Train Loss = 0.8035, Train Accuracy = 71.1039
#   Validation Loss = 1.1943, Validation Accuracy = 56.8182
# Epoch 26:
#   Train Loss = 0.7949, Train Accuracy = 71.5097
#   Validation Loss = 1.1968, Validation Accuracy = 55.5195
# Epoch 27:
#   Train Loss = 0.7845, Train Accuracy = 71.8344
#   Validation Loss = 1.1958, Validation Accuracy = 55.8442
# Epoch 28:
#   Train Loss = 0.7750, Train Accuracy = 71.3474
#   Validation Loss = 1.2027, Validation Accuracy = 57.4675
# Epoch 29:
#   Train Loss = 0.7681, Train Accuracy = 71.8344
#   Validation Loss = 1.2141, Validation Accuracy = 56.1688
# Epoch 30:
#   Train Loss = 0.7588, Train Accuracy = 72.3214
#   Validation Loss = 1.2213, Validation Accuracy = 54.8701
# Epoch 31:
#   Train Loss = 0.7466, Train Accuracy = 73.1331
#   Validation Loss = 1.2418, Validation Accuracy = 54.2208
# Epoch 32:
#   Train Loss = 0.7391, Train Accuracy = 73.2955
#   Validation Loss = 1.2313, Validation Accuracy = 55.5195
# Epoch 33:
#   Train Loss = 0.7270, Train Accuracy = 73.7013
#   Validation Loss = 1.2481, Validation Accuracy = 53.8961
# Epoch 34:
#   Train Loss = 0.7201, Train Accuracy = 73.5390
#   Validation Loss = 1.2475, Validation Accuracy = 54.2208
# Epoch 35:
#   Train Loss = 0.7129, Train Accuracy = 73.5390
#   Validation Loss = 1.2611, Validation Accuracy = 53.5714
# Epoch 36:
#   Train Loss = 0.7109, Train Accuracy = 73.7825
#   Validation Loss = 1.2670, Validation Accuracy = 53.8961
# Epoch 37:
#   Train Loss = 0.6934, Train Accuracy = 75.2435
#   Validation Loss = 1.2743, Validation Accuracy = 54.5455
# Epoch 38:
#   Train Loss = 0.6863, Train Accuracy = 75.5682
#   Validation Loss = 1.2721, Validation Accuracy = 53.8961
# Epoch 39:
#   Train Loss = 0.6813, Train Accuracy = 75.1623
#   Validation Loss = 1.2877, Validation Accuracy = 53.8961
# Epoch 40:
#   Train Loss = 0.6641, Train Accuracy = 76.6234
#   Validation Loss = 1.2894, Validation Accuracy = 54.2208
# Epoch 41:
#   Train Loss = 0.6614, Train Accuracy = 76.3799
#   Validation Loss = 1.3073, Validation Accuracy = 54.2208
# Epoch 42:
#   Train Loss = 0.6450, Train Accuracy = 76.7857
#   Validation Loss = 1.3079, Validation Accuracy = 53.8961
# Epoch 43:
#   Train Loss = 0.6380, Train Accuracy = 77.7597
#   Validation Loss = 1.3327, Validation Accuracy = 53.5714
# Epoch 44:
#   Train Loss = 0.6310, Train Accuracy = 77.5162
#   Validation Loss = 1.3386, Validation Accuracy = 52.5974
# Epoch 45:
#   Train Loss = 0.6325, Train Accuracy = 77.3539
#   Validation Loss = 1.3536, Validation Accuracy = 52.2727
# Epoch 46:
#   Train Loss = 0.6163, Train Accuracy = 79.1396
#   Validation Loss = 1.3406, Validation Accuracy = 52.5974
# Epoch 47:
#   Train Loss = 0.6166, Train Accuracy = 78.0844
#   Validation Loss = 1.3516, Validation Accuracy = 52.9221
# Epoch 48:
#   Train Loss = 0.6052, Train Accuracy = 78.1656
#   Validation Loss = 1.3654, Validation Accuracy = 52.2727
# Epoch 49:
#   Train Loss = 0.5926, Train Accuracy = 79.1396
#   Validation Loss = 1.4040, Validation Accuracy = 51.9481
# Epoch 50:
#   Train Loss = 0.5823, Train Accuracy = 79.4643
#   Validation Loss = 1.3882, Validation Accuracy = 51.9481
# Epoch 51:
#   Train Loss = 0.5814, Train Accuracy = 79.7078
#   Validation Loss = 1.4125, Validation Accuracy = 53.8961
# Epoch 52:
#   Train Loss = 0.5761, Train Accuracy = 80.0325
#   Validation Loss = 1.4076, Validation Accuracy = 50.9740
# Epoch 53:
#   Train Loss = 0.5667, Train Accuracy = 79.0584
#   Validation Loss = 1.4186, Validation Accuracy = 51.9481
# Epoch 54:
#   Train Loss = 0.5542, Train Accuracy = 80.9253
#   Validation Loss = 1.4394, Validation Accuracy = 52.5974
# Epoch 55:
#   Train Loss = 0.5403, Train Accuracy = 81.3312
#   Validation Loss = 1.4616, Validation Accuracy = 51.6234
# Epoch 56:
#   Train Loss = 0.5386, Train Accuracy = 81.8994
#   Validation Loss = 1.4673, Validation Accuracy = 50.0000
# Epoch 57:
#   Train Loss = 0.5271, Train Accuracy = 81.3312
#   Validation Loss = 1.4873, Validation Accuracy = 50.9740
# Epoch 58:
#   Train Loss = 0.5195, Train Accuracy = 82.3052
#   Validation Loss = 1.4954, Validation Accuracy = 50.9740
# Epoch 59:
#   Train Loss = 0.5124, Train Accuracy = 82.5487
#   Validation Loss = 1.5067, Validation Accuracy = 50.3247
# Epoch 60:
#   Train Loss = 0.5057, Train Accuracy = 82.8734
#   Validation Loss = 1.5298, Validation Accuracy = 50.9740
# Epoch 61:
#   Train Loss = 0.5015, Train Accuracy = 82.7110
#   Validation Loss = 1.5236, Validation Accuracy = 50.0000
# Epoch 62:
#   Train Loss = 0.4891, Train Accuracy = 83.6851
#   Validation Loss = 1.5597, Validation Accuracy = 50.0000
# Epoch 63:
#   Train Loss = 0.4834, Train Accuracy = 83.6851
#   Validation Loss = 1.5597, Validation Accuracy = 49.6753
# Epoch 64:
#   Train Loss = 0.4748, Train Accuracy = 83.8474
#   Validation Loss = 1.6136, Validation Accuracy = 51.2987
# Epoch 65:
#   Train Loss = 0.4705, Train Accuracy = 84.7403
#   Validation Loss = 1.5951, Validation Accuracy = 50.6494
# Epoch 66:
#   Train Loss = 0.4643, Train Accuracy = 84.1721
#   Validation Loss = 1.6144, Validation Accuracy = 48.7013
# Epoch 67:
#   Train Loss = 0.4546, Train Accuracy = 85.1461
#   Validation Loss = 1.6285, Validation Accuracy = 48.3766
# Epoch 68:
#   Train Loss = 0.4482, Train Accuracy = 85.0649
#   Validation Loss = 1.6354, Validation Accuracy = 48.7013
# Epoch 69:
#   Train Loss = 0.4441, Train Accuracy = 85.9578
#   Validation Loss = 1.6751, Validation Accuracy = 49.6753
# Epoch 70:
#   Train Loss = 0.4397, Train Accuracy = 85.3896
#   Validation Loss = 1.6641, Validation Accuracy = 49.3506
# Epoch 71:
#   Train Loss = 0.4332, Train Accuracy = 86.1201
#   Validation Loss = 1.7066, Validation Accuracy = 48.7013
# Epoch 72:
#   Train Loss = 0.4235, Train Accuracy = 86.6071
#   Validation Loss = 1.7017, Validation Accuracy = 49.6753
# Epoch 73:
#   Train Loss = 0.4193, Train Accuracy = 86.8506
#   Validation Loss = 1.7107, Validation Accuracy = 48.0519
# Epoch 74:
#   Train Loss = 0.4072, Train Accuracy = 87.2565
#   Validation Loss = 1.7300, Validation Accuracy = 48.3766
# Epoch 75:
#   Train Loss = 0.4021, Train Accuracy = 87.0130
#   Validation Loss = 1.7476, Validation Accuracy = 49.3506
# Epoch 76:
#   Train Loss = 0.3984, Train Accuracy = 87.5812
#   Validation Loss = 1.7534, Validation Accuracy = 49.3506
# Epoch 77:
#   Train Loss = 0.3884, Train Accuracy = 87.2565
#   Validation Loss = 1.7562, Validation Accuracy = 48.3766
# Epoch 78:
#   Train Loss = 0.3820, Train Accuracy = 88.5552
#   Validation Loss = 1.7807, Validation Accuracy = 49.0260
# Epoch 79:
#   Train Loss = 0.3776, Train Accuracy = 88.3929
#   Validation Loss = 1.8007, Validation Accuracy = 48.0519
# Epoch 80:
#   Train Loss = 0.3731, Train Accuracy = 89.4481
#   Validation Loss = 1.8051, Validation Accuracy = 47.4026
# Epoch 81:
#   Train Loss = 0.3668, Train Accuracy = 89.0422
#   Validation Loss = 1.8228, Validation Accuracy = 49.6753
# Epoch 82:
#   Train Loss = 0.3592, Train Accuracy = 89.1234
#   Validation Loss = 1.8395, Validation Accuracy = 49.0260
# Epoch 83:
#   Train Loss = 0.3528, Train Accuracy = 89.2045
#   Validation Loss = 1.8652, Validation Accuracy = 47.7273
# Epoch 84:
#   Train Loss = 0.3444, Train Accuracy = 90.0162
#   Validation Loss = 1.8592, Validation Accuracy = 49.3506
# Epoch 85:
#   Train Loss = 0.3430, Train Accuracy = 89.9351
#   Validation Loss = 1.9092, Validation Accuracy = 48.0519
# Epoch 86:
#   Train Loss = 0.3369, Train Accuracy = 90.3409
#   Validation Loss = 1.8876, Validation Accuracy = 50.3247
# Epoch 87:
#   Train Loss = 0.3305, Train Accuracy = 90.0974
#   Validation Loss = 1.9142, Validation Accuracy = 49.0260
# Epoch 88:
#   Train Loss = 0.3264, Train Accuracy = 91.0714
#   Validation Loss = 1.9417, Validation Accuracy = 48.3766
# Epoch 89:
#   Train Loss = 0.3164, Train Accuracy = 90.9903
#   Validation Loss = 1.9692, Validation Accuracy = 48.3766
# Epoch 90:
#   Train Loss = 0.3185, Train Accuracy = 90.9903
#   Validation Loss = 1.9843, Validation Accuracy = 48.7013
# Epoch 91:
#   Train Loss = 0.3094, Train Accuracy = 92.6136
#   Validation Loss = 1.9782, Validation Accuracy = 47.7273
# Epoch 92:
#   Train Loss = 0.3029, Train Accuracy = 91.7208
#   Validation Loss = 1.9882, Validation Accuracy = 48.0519
# Epoch 93:
#   Train Loss = 0.2937, Train Accuracy = 92.2078
#   Validation Loss = 2.0308, Validation Accuracy = 48.7013
# Epoch 94:
#   Train Loss = 0.2915, Train Accuracy = 91.6396
#   Validation Loss = 2.0314, Validation Accuracy = 48.0519
# Epoch 95:
#   Train Loss = 0.2835, Train Accuracy = 93.3442
#   Validation Loss = 2.0783, Validation Accuracy = 49.3506
# Epoch 96:
#   Train Loss = 0.2773, Train Accuracy = 92.8571
#   Validation Loss = 2.0861, Validation Accuracy = 47.7273
# Epoch 97:
#   Train Loss = 0.2791, Train Accuracy = 92.6136
#   Validation Loss = 2.1182, Validation Accuracy = 47.7273
# Epoch 98:
#   Train Loss = 0.2680, Train Accuracy = 93.1818
#   Validation Loss = 2.1153, Validation Accuracy = 48.7013
# Epoch 99:
#   Train Loss = 0.2618, Train Accuracy = 93.8312
#   Validation Loss = 2.1164, Validation Accuracy = 47.7273
# Epoch 100:
#   Train Loss = 0.2563, Train Accuracy = 93.3442
#   Validation Loss = 2.1379, Validation Accuracy = 48.0519
# Epoch 101:
#   Train Loss = 0.2503, Train Accuracy = 93.8312
#   Validation Loss = 2.1677, Validation Accuracy = 48.3766
# Epoch 102:
#   Train Loss = 0.2485, Train Accuracy = 94.0747
#   Validation Loss = 2.1596, Validation Accuracy = 47.7273
# Epoch 103:
#   Train Loss = 0.2414, Train Accuracy = 94.6429
#   Validation Loss = 2.1830, Validation Accuracy = 48.7013
# Epoch 104:
#   Train Loss = 0.2403, Train Accuracy = 94.5617
#   Validation Loss = 2.2682, Validation Accuracy = 47.7273
# Epoch 105:
#   Train Loss = 0.2380, Train Accuracy = 94.2370
#   Validation Loss = 2.2592, Validation Accuracy = 47.7273
# Epoch 106:
#   Train Loss = 0.2266, Train Accuracy = 94.6429
#   Validation Loss = 2.2629, Validation Accuracy = 49.3506
# Epoch 107:
#   Train Loss = 0.2313, Train Accuracy = 94.7240
#   Validation Loss = 2.3051, Validation Accuracy = 49.3506
# Epoch 108:
#   Train Loss = 0.2235, Train Accuracy = 94.8864
#   Validation Loss = 2.3346, Validation Accuracy = 49.0260
# Epoch 109:
#   Train Loss = 0.2110, Train Accuracy = 95.2922
#   Validation Loss = 2.3081, Validation Accuracy = 48.3766
# Epoch 110:
#   Train Loss = 0.2075, Train Accuracy = 95.8604
#   Validation Loss = 2.3626, Validation Accuracy = 48.3766
# Epoch 111:
#   Train Loss = 0.2049, Train Accuracy = 95.6169
#   Validation Loss = 2.3559, Validation Accuracy = 50.3247
# Epoch 112:
#   Train Loss = 0.1980, Train Accuracy = 96.5097
#   Validation Loss = 2.4185, Validation Accuracy = 48.0519
# Epoch 113:
#   Train Loss = 0.1955, Train Accuracy = 95.9416
#   Validation Loss = 2.4411, Validation Accuracy = 48.3766
# Epoch 114:
#   Train Loss = 0.1928, Train Accuracy = 95.6981
#   Validation Loss = 2.4078, Validation Accuracy = 49.0260
# Epoch 115:
#   Train Loss = 0.1848, Train Accuracy = 96.1039
#   Validation Loss = 2.4391, Validation Accuracy = 50.6494
# Epoch 116:
#   Train Loss = 0.1814, Train Accuracy = 96.5909
#   Validation Loss = 2.4586, Validation Accuracy = 49.0260
# Epoch 117:
#   Train Loss = 0.1750, Train Accuracy = 96.9968
#   Validation Loss = 2.4977, Validation Accuracy = 48.3766
# Epoch 118:
#   Train Loss = 0.1738, Train Accuracy = 96.7532
#   Validation Loss = 2.5246, Validation Accuracy = 47.0779
# Epoch 119:
#   Train Loss = 0.1714, Train Accuracy = 96.5909
#   Validation Loss = 2.5510, Validation Accuracy = 49.0260
# Epoch 120:
#   Train Loss = 0.1654, Train Accuracy = 97.3214
#   Validation Loss = 2.5312, Validation Accuracy = 50.0000
# Epoch 121:
#   Train Loss = 0.1604, Train Accuracy = 97.4026
#   Validation Loss = 2.5683, Validation Accuracy = 49.3506
# Epoch 122:
#   Train Loss = 0.1592, Train Accuracy = 96.9968
#   Validation Loss = 2.6226, Validation Accuracy = 48.7013
# Epoch 123:
#   Train Loss = 0.1558, Train Accuracy = 97.6461
#   Validation Loss = 2.6134, Validation Accuracy = 49.6753
# Epoch 124:
#   Train Loss = 0.1470, Train Accuracy = 97.9708
#   Validation Loss = 2.6577, Validation Accuracy = 49.6753
# Epoch 125:
#   Train Loss = 0.1450, Train Accuracy = 97.9708
#   Validation Loss = 2.6760, Validation Accuracy = 49.6753
# Epoch 126:
#   Train Loss = 0.1395, Train Accuracy = 97.8896
#   Validation Loss = 2.6831, Validation Accuracy = 49.0260
# Epoch 127:
#   Train Loss = 0.1372, Train Accuracy = 98.1331
#   Validation Loss = 2.7256, Validation Accuracy = 49.3506
# Epoch 128:
#   Train Loss = 0.1326, Train Accuracy = 98.3766
#   Validation Loss = 2.7129, Validation Accuracy = 49.6753
# Epoch 129:
#   Train Loss = 0.1288, Train Accuracy = 98.4578
#   Validation Loss = 2.7633, Validation Accuracy = 48.7013
# Epoch 130:
#   Train Loss = 0.1262, Train Accuracy = 98.1331
#   Validation Loss = 2.8024, Validation Accuracy = 48.3766
# Epoch 131:
#   Train Loss = 0.1224, Train Accuracy = 98.5390
#   Validation Loss = 2.8052, Validation Accuracy = 49.6753
# Epoch 132:
#   Train Loss = 0.1202, Train Accuracy = 98.8636
#   Validation Loss = 2.8611, Validation Accuracy = 47.7273
# Epoch 133:
#   Train Loss = 0.1174, Train Accuracy = 98.7825
#   Validation Loss = 2.8361, Validation Accuracy = 49.3506
# Epoch 134:
#   Train Loss = 0.1122, Train Accuracy = 99.1071
#   Validation Loss = 2.8590, Validation Accuracy = 48.7013
# Epoch 135:
#   Train Loss = 0.1113, Train Accuracy = 99.3506
#   Validation Loss = 2.9044, Validation Accuracy = 48.7013
# Epoch 136:
#   Train Loss = 0.1070, Train Accuracy = 99.3506
#   Validation Loss = 2.9297, Validation Accuracy = 47.7273
# Epoch 137:
#   Train Loss = 0.1024, Train Accuracy = 99.2695
#   Validation Loss = 2.9443, Validation Accuracy = 49.0260
# Epoch 138:
#   Train Loss = 0.1008, Train Accuracy = 99.3506
#   Validation Loss = 3.0264, Validation Accuracy = 47.7273
# Epoch 139:
#   Train Loss = 0.0987, Train Accuracy = 99.4318
#   Validation Loss = 3.0027, Validation Accuracy = 49.0260
# Epoch 140:
#   Train Loss = 0.0973, Train Accuracy = 99.3506
#   Validation Loss = 3.0287, Validation Accuracy = 48.3766
# Epoch 141:
#   Train Loss = 0.0931, Train Accuracy = 99.5942
#   Validation Loss = 3.0382, Validation Accuracy = 49.3506
# Epoch 142:
#   Train Loss = 0.0903, Train Accuracy = 99.4318
#   Validation Loss = 3.0579, Validation Accuracy = 49.3506
# Epoch 143:
#   Train Loss = 0.0874, Train Accuracy = 99.7565
#   Validation Loss = 3.0817, Validation Accuracy = 49.3506
# Epoch 144:
#   Train Loss = 0.0852, Train Accuracy = 99.7565
#   Validation Loss = 3.0899, Validation Accuracy = 49.6753
# Epoch 145:
#   Train Loss = 0.0831, Train Accuracy = 99.5942
#   Validation Loss = 3.1480, Validation Accuracy = 49.0260
# Epoch 146:
#   Train Loss = 0.0813, Train Accuracy = 99.7565
#   Validation Loss = 3.1387, Validation Accuracy = 49.3506
# Epoch 147:
#   Train Loss = 0.0775, Train Accuracy = 99.7565
#   Validation Loss = 3.1763, Validation Accuracy = 47.4026
# Epoch 148:
#   Train Loss = 0.0766, Train Accuracy = 99.9188
#   Validation Loss = 3.2351, Validation Accuracy = 47.7273
# Epoch 149:
#   Train Loss = 0.0747, Train Accuracy = 99.8377
#   Validation Loss = 3.2263, Validation Accuracy = 46.7532
# Epoch 150:
#   Train Loss = 0.0723, Train Accuracy = 99.9188
#   Validation Loss = 3.2414, Validation Accuracy = 48.3766
# <All keys matched successfully>

# %% [markdown]
# BOOSTING MY ACCURACY

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier  # Example classifier
from sklearn.metrics import accuracy_score

# Example: Random Forest Classifier
model = RandomForestClassifier()

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit grid search
grid_search.fit(X_train, y_train)

# Best parameters and best accuracy score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print(f"Best Parameters: {best_params}")
print(f"Best Accuracy: {best_score}")
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 300}
# Best Accuracy: 0.7102629933181922

# %%
# After training the model with the best parameters
best_model = grid_search.best_estimator_

# Predict on the test set
y_pred = best_model.predict(X_test)

# Calculate accuracy on test data
test_accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Accuracy: 0.6948051948051948

# %% [markdown]
# 4Th module DL recommendation

# %%
import pandas as pd

# Load the dataset
file_path = '/content/drive/My Drive/numerical_gender_mental_health_dataset.xlsx'
data = pd.read_excel(file_path)

# Function to identify top affected symptoms and provide suggestions
def get_top_affected_symptoms_with_suggestions(row):
    # List of symptom columns - Corrected column names
    symptom_columns = [
        'Sleep', 'Appetite', 'Fatigue', 'Worthlessness', 'Concentration',
        'Agitation', 'Suicidal Ideation', 'Sleep Disturbance', 'Aggression', 'Panic Attacks',
        'Hopelessness', 'Restlessness', 'Low Energy', 'Interest'
    ]

    # Define symptom-to-suggestion mapping - Updated for corrected column names
    suggestions_mapping = {
        'Sleep': 'Try improving sleep hygiene, such as a regular sleep schedule or relaxation techniques.',
        'Appetite': 'Consider small, frequent meals or consulting a nutritionist for tailored advice.',
        'Fatigue': 'Take short breaks, engage in light exercise, and ensure a balanced diet.',
        'Worthlessness': 'Reach out to support groups or talk to a counselor for emotional guidance.',
        'Concentration': 'Practice mindfulness exercises or cognitive behavioral techniques.',
        'Agitation': 'Try relaxation techniques such as deep breathing or meditation.',
        'Suicidal Ideation': 'Please reach out to a crisis helpline or mental health professional immediately.',
        'Sleep Disturbance': 'Establish a calming bedtime routine and limit screen time before bed.',
        'Aggression': 'Engage in calming activities like yoga or talk therapy to manage anger.',
        'Panic Attacks': 'Practice deep breathing exercises and consider therapy for anxiety management.',
        'Hopelessness': 'Connect with support groups or seek therapy to work through feelings of despair.',
        'Restlessness': 'Consider relaxation strategies or yoga to release built-up tension.',
        'Low Energy': 'Engage in mild physical activity and ensure proper nutrition and hydration.',
        'Interest': 'Explore hobbies or activities that might reignite interest and energy.'
    }

    # Find the maximum severity value
    max_severity = row[symptom_columns].max()

    # Get all symptoms with that max severity
    affected_symptoms = row[symptom_columns][row[symptom_columns] == max_severity].index.tolist()

    # Gather suggestions for the affected symptoms
    suggestions = [suggestions_mapping[symptom] for symptom in affected_symptoms]

    # Return both the affected symptoms and their corresponding suggestions
    return affected_symptoms, suggestions

# Apply the function to the dataset
data[['Top Affected Symptoms', 'Suggestions']] = data.apply(get_top_affected_symptoms_with_suggestions, axis=1, result_type="expand")

# Save the updated dataset with suggestions (optional)
data.to_excel('/content/drive/My Drive/updated_mental_health_with_suggestions.xlsx', index=False)

# Show the updated dataset with the "Top Affected Symptoms" and "Suggestions"
data[['Sleep', 'Fatigue', 'Sleep Disturbance', 'Low Energy', 'Top Affected Symptoms', 'Suggestions']].head() # Corrected column names in head()
# Out:
#    Sleep  Fatigue  Sleep Disturbance  Low Energy  \
# 0      5        4                  3           3
# 1      1        3                  2           4
# 2      4        3                  5           4
# 3      1        3                  4           2
# 4      2        4                  4           2
#
#                                Top Affected Symptoms  \
# 0  [Sleep, Appetite, Concentration, Suicidal Idea...
# 1  [Appetite, Panic Attacks, Restlessness, Interest]
# 2  [Agitation, Sleep Disturbance, Panic Attacks, ...
# 3                               [Appetite, Interest]
# 4          [Concentration, Agitation, Panic Attacks]
#
#                                          Suggestions
# 0  [Try improving sleep hygiene, such as a regula...
# 1  [Consider small, frequent meals or consulting ...
# 2  [Try relaxation techniques such as deep breath...
# 3  [Consider small, frequent meals or consulting ...
# 4  [Practice mindfulness exercises or cognitive b...

# %%
USER INTERFACE

# %%
# !pip install streamlit pyngrok
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (1.45.0)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.11/dist-packages (7.2.5)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.4)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.13.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.36.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
# %%writefile app.py
import streamlit as st

st.set_page_config(page_title="Mental Health Depression Detector", layout="centered")

st.title("🧠 Mental Health Depression Detection")
st.markdown("Please fill out the form below to assess depression severity and get personalized recommendations.")

with st.form("mental_health_form"):
    st.markdown("### Demographic Information")
    age = st.slider("Age", 10, 100, 25)
    gender = st.selectbox("Gender", ["Male", "Female", "Other"])
    occupation = st.text_input("Occupation")
    location = st.text_input("Location")
    marital_status = st.selectbox("Marital Status", ["Single", "Married", "Divorced", "Widowed"])
    education_level = st.selectbox("Education Level", ["High School", "Bachelor's", "Master's", "Doctorate", "Other"])

    st.markdown("### Symptom Ratings (1 = None, 5 = Severe)")
    symptoms = {
        "Sleep Issue": st.slider("Sleep Issue", 1, 5),
        "Appetite Issue": st.slider("Appetite Issue", 1, 5),
        "Lack of Interest": st.slider("Lack of Interest", 1, 5),
        "Fatigue": st.slider("Fatigue", 1, 5),
        "Worthlessness": st.slider("Feelings of Worthlessness", 1, 5),
        "Concentration Issue": st.slider("Concentration Issue", 1, 5),
        "Agitation": st.slider("Agitation", 1, 5),
        "Suicidal Ideation": st.slider("Suicidal Ideation", 1, 5),
        "Sleep Disturbance": st.slider("Sleep Disturbance", 1, 5),
        "Aggression": st.slider("Aggression", 1, 5),
        "Panic Attacks": st.slider("Panic Attacks", 1, 5),
        "Hopelessness": st.slider("Hopelessness", 1, 5),
        "Restlessness": st.slider("Restlessness", 1, 5),
        "Low Energy": st.slider("Low Energy", 1, 5)
    }

    submit = st.form_submit_button("Predict Depression Severity")

if submit:
    total_score = sum(symptoms.values())
    if total_score < 35:
        severity = "Mild"
    elif total_score < 55:
        severity = "Moderate"
    else:
        severity = "Severe"

    st.subheader(f"🩺 Depression Severity: **{severity}**")

    st.markdown("### Recommendations:")
    if symptoms["Sleep Issue"] >= 4 or symptoms["Sleep Disturbance"] >= 4:
        st.write("- Establish a regular sleep routine. Limit caffeine and screen time before bed.")
    if symptoms["Suicidal Ideation"] >= 4:
        st.write("- Seek emergency mental health support or call a crisis hotline immediately.")
    if symptoms["Fatigue"] >= 4 or symptoms["Low Energy"] >= 4:
        st.write("- Light exercise and hydration can help restore energy.")
    if symptoms["Hopelessness"] >= 4 or symptoms["Worthlessness"] >= 4:
        st.write("- Talk to a counselor or therapist. Journaling may also help process emotions.")
    if symptoms["Panic Attacks"] >= 4:
        st.write("- Try deep breathing exercises and avoid caffeine.")
    if symptoms["Aggression"] >= 4:
        st.write("- Practice anger management techniques or speak to a therapist.")
    if symptoms["Appetite Issue"] >= 4:
        st.write("- Eat small meals regularly; consult a dietitian if needed.")
    if symptoms["Lack of Interest"] >= 4:
        st.write("- Start with small enjoyable activities, even if motivation is low.")
    if symptoms["Restlessness"] >= 4:
        st.write("- Try grounding techniques or engage in structured tasks.")
    if symptoms["Concentration Issue"] >= 4:
        st.write("- Use lists, reminders, and reduce multitasking.")

    st.write("- General Tip: Mindfulness, CBT techniques, and social support are very beneficial.")
# Out:
# Overwriting app.py

# %%
# !pip install streamlit pyngrok --quiet

# %%
from pyngrok import ngrok
import threading
import os
import time

# Function to run the Streamlit app
def run_app():
    os.system("streamlit run app.py")

# Start the app in a separate thread
thread = threading.Thread(target=run_app)
thread.start()

# Wait a moment for the server to start
time.sleep(5)

# Expose the Streamlit app to the web
public_url = ngrok.connect(8501)
print("Streamlit app is running at:", public_url)
# Out:
# Streamlit app is running at: NgrokTunnel: "https://75c2-35-247-71-66.ngrok-free.app" -> "http://localhost:8501"

# %% [markdown]
# local server module

# %%
# !pip install streamlit pyngrok --quiet

# %%
# %%writefile app.py
import streamlit as st

st.set_page_config(page_title="Mental Health Depression Detector", layout="centered")

st.title("🧠 Mental Health Depression Detection")
st.markdown("Please fill out the form below to assess depression severity and get personalized recommendations.")

with st.form("mental_health_form"):
    st.markdown("### Demographic Information")
    age = st.slider("Age", 10, 100, 25)
    gender = st.selectbox("Gender", ["Male", "Female", "Other"])
    occupation = st.text_input("Occupation")
    location = st.text_input("Location")
    marital_status = st.selectbox("Marital Status", ["Single", "Married", "Divorced", "Widowed"])
    education_level = st.selectbox("Education Level", ["High School", "Bachelor's", "Master's", "Doctorate", "Other"])

    st.markdown("### Symptom Ratings (1 = None, 5 = Severe)")
    symptoms = {
        "Sleep Issue": st.slider("Sleep Issue", 1, 5),
        "Appetite Issue": st.slider("Appetite Issue", 1, 5),
        "Lack of Interest": st.slider("Lack of Interest", 1, 5),
        "Fatigue": st.slider("Fatigue", 1, 5),
        "Worthlessness": st.slider("Feelings of Worthlessness", 1, 5),
        "Concentration Issue": st.slider("Concentration Issue", 1, 5),
        "Agitation": st.slider("Agitation", 1, 5),
        "Suicidal Ideation": st.slider("Suicidal Ideation", 1, 5),
        "Sleep Disturbance": st.slider("Sleep Disturbance", 1, 5),
        "Aggression": st.slider("Aggression", 1, 5),
        "Panic Attacks": st.slider("Panic Attacks", 1, 5),
        "Hopelessness": st.slider("Hopelessness", 1, 5),
        "Restlessness": st.slider("Restlessness", 1, 5),
        "Low Energy": st.slider("Low Energy", 1, 5)
    }

    submit = st.form_submit_button("Predict Depression Severity")

if submit:
    total_score = sum(symptoms.values())
    if total_score < 35:
        severity = "Mild"
    elif total_score < 55:
        severity = "Moderate"
    else:
        severity = "Severe"

    st.subheader(f"🩺 Depression Severity: **{severity}**")

    st.markdown("### Recommendations:")
    if symptoms["Sleep Issue"] >= 4 or symptoms["Sleep Disturbance"] >= 4:
        st.write("- Establish a regular sleep routine. Limit caffeine and screen time before bed.")
    if symptoms["Suicidal Ideation"] >= 4:
        st.write("- Seek emergency mental health support or call a crisis hotline immediately.")
    if symptoms["Fatigue"] >= 4 or symptoms["Low Energy"] >= 4:
        st.write("- Light exercise and hydration can help restore energy.")
    if symptoms["Hopelessness"] >= 4 or symptoms["Worthlessness"] >= 4:
        st.write("- Talk to a counselor or therapist. Journaling may also help process emotions.")
    if symptoms["Panic Attacks"] >= 4:
        st.write("- Try deep breathing exercises and avoid caffeine.")
    if symptoms["Aggression"] >= 4:
        st.write("- Practice anger management techniques or speak to a therapist.")
    if symptoms["Appetite Issue"] >= 4:
        st.write("- Eat small meals regularly; consult a dietitian if needed.")
    if symptoms["Lack of Interest"] >= 4:
        st.write("- Start with small enjoyable activities, even if motivation is low.")
    if symptoms["Restlessness"] >= 4:
        st.write("- Try grounding techniques or engage in structured tasks.")
    if symptoms["Concentration Issue"] >= 4:
        st.write("- Use lists, reminders, and reduce multitasking.")

    st.write("- General Tip: Mindfulness, CBT techniques, and social support are very beneficial.")
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok, conf
import threading
import os
import time

# ✅ Replace 'YOUR_AUTHTOKEN' with your actual ngrok authtoken
conf.get_default().auth_token = "2wToPrQ82Amsyfbpl8wdi9Wo8zK_3yCWf1ErGrKs9Kqjq6Wze"  # Corrected authtoken format

# Start Streamlit app in the background
def run():
    os.system("streamlit run app.py")

thread = threading.Thread(target=run)
thread.start()

# Wait for server to launch
time.sleep(5)

# Expose app on public URL
public_url = ngrok.connect(8501)  # Corrected to connect once
print("✅ Your Streamlit app is running at:", public_url)
# Out:
# ✅ Your Streamlit app is running at: NgrokTunnel: "https://f447-34-106-71-142.ngrok-free.app" -> "http://localhost:8501"

# %% [markdown]
# CODE TO PRODUCE THE WeB APPLICATION
